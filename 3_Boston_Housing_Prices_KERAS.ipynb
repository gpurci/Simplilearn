# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
#tf.enable_eager_execution()

# %%
from sklearn.preprocessing import Normalizer

# %% [markdown]
# ### Collect Data

# %%
(train_x, train_y),(test_x, test_y) = tf.keras.datasets.boston_housing.load_data(test_split=0.2)
# Out:
# ...
# 57344/57026 [==============================] - 0s 0us/step

# %%
train_x = train_x.astype('float32')
train_y = train_y.astype('float32')
test_x = test_x.astype('float32')
test_y = test_y.astype('float32')

# %%
transformer = Normalizer()
train_x = transformer.fit_transform(train_x)
test_x = transformer.fit_transform(test_x)

# %% [markdown]
# ### Building the graph in Keras

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Reshape((13,),input_shape=(13,)))

model.add(tf.keras.layers.Dense(1000,activation='relu'))
model.add(tf.keras.layers.Dense(500,activation='relu'))
model.add(tf.keras.layers.Dense(100,activation='relu'))

model.add(tf.keras.layers.Dense(1))
model.compile(optimizer='sgd', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# reshape_1 (Reshape)          (None, 13)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              14000
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               50100
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 101
# ...
# Total params: 564,701
# Trainable params: 564,701
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Execute the Graph

# %%
model.fit(train_x, train_y, epochs=100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 8ms/step - loss: 65.3726
# Epoch 2/100
# 13/13 [==============================] - 0s 8ms/step - loss: 62.2690
# Epoch 3/100
# 13/13 [==============================] - 0s 8ms/step - loss: 65.4488
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 68.1407
# Epoch 5/100
# 13/13 [==============================] - 0s 8ms/step - loss: 66.6182
# Epoch 6/100
# 13/13 [==============================] - 0s 8ms/step - loss: 65.7248
# Epoch 7/100
# 13/13 [==============================] - 0s 8ms/step - loss: 67.2684
# Epoch 8/100
# 13/13 [==============================] - 0s 8ms/step - loss: 70.6770
# Epoch 9/100
# 13/13 [==============================] - 0s 10ms/step - loss: 64.5378
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 61.3511
# Epoch 11/100
# 13/13 [==============================] - 0s 8ms/step - loss: 65.2626
# Epoch 12/100
# ...

# %%
model.get_weights()
# Out:
# [array([[ 0.2189745 , -0.13287076,  0.03021809, ...,  0.13780072,
#           0.20475635,  0.10422213],
#         [-0.12365807, -0.07010427,  0.13415189, ...,  0.02969351,
#          -0.19782999,  1.4520109 ],
#         [-0.1761277 ,  0.04966518,  0.02486407, ...,  0.06511021,
#           0.11180615, -0.15881264],
#         ...,
#         [-0.03362612, -0.15544392, -0.07344037, ...,  0.06856313,
#          -0.22234815, -0.2391171 ],
#         [-0.02401195,  0.07092556,  0.24988295, ..., -0.15228572,
#          -0.02805932,  0.54735386],
#         [-0.21997288, -0.18491374, -0.0573389 , ...,  0.02664086,
#           0.20612103, -0.47344965]], dtype=float32),
#  array([ 0.        ,  0.        , -0.14681135, -0.43292522,  0.22837767,
#         -0.2089161 , -0.09424414, -0.31360665,  0.        , -0.6141519 ,
#          0.        ,  0.        , -0.05583512, -0.12421312, -0.8679966 ,
#         -0.03004045,  0.        , -0.01716167,  0.16347961, -0.45551056,
# ...

# %% [markdown]
# ### Save the model

# %%
model.save('boston_housing_lr.h5')

# %%
# !ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 14232 May 29 10:26 boston_housing_lr.h5
# drwxr-xr-x 1 root root  4096 May  6 13:44 sample_data

# %%
from google.colab import files

files.download('boston_housing_lr.h5')
