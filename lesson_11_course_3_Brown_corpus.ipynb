# %% [markdown]
# The Brown University Standard Corpus of Present-Day American English also known popularly as Brown Corpus was compiled in the 1960s as a general corpus in the field of corpus linguistics. It contains 500 samples of English language text, totaling roughly one million words, compiled from works published in the United States in 1961.

# %%
import regex as re

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
with open('/content/brown_corpus_ca10.txt', 'r') as myFile:
  data = myFile.read()

# %%
data = re.sub(r'\n+', '\n', data)

# %%
data2 = re.sub(r'((/\.)|(/[^\s\.]*))', '', data)

# %%
data2[:1000]
# Out:
# "\n\tVincent G. Ierulli has been appointed temporary assistant district attorney , it was announced Monday by Charles E. Raymond , District Attorney .\n\tIerulli will replace Desmond D. Connall who has been called to active military service but is expected back on the job by March 31 .\n\tIerulli , 29 , has been practicing in Portland since November , 1959 .\nHe is a graduate of Portland University and the Northwestern College of Law .\nHe is married and the father of three children .\n\tHelping foreign countries to build a sound political structure is more important than aiding them economically , E. M. Martin , assistant secretary of state for economic affairs told members of the World Affairs Council Monday night .\n\tMartin , who has been in office in Washington , D. C. , for 13 months spoke at the council's annual meeting at the Multnomah Hotel .\nHe told some 350 persons that the United States' challenge was to help countries build their own societies their own ways , following
# ...

# %%
for i, line in enumerate(data2.split('\n')):
  if i > 10:
    break
  print(str(i) + ':\t' + line)
# Out:
# 0:
# 1:		Vincent G. Ierulli has been appointed temporary assistant district attorney , it was announced Monday by Charles E. Raymond , District Attorney .
# 2:		Ierulli will replace Desmond D. Connall who has been called to active military service but is expected back on the job by March 31 .
# 3:		Ierulli , 29 , has been practicing in Portland since November , 1959 .
# 4:	He is a graduate of Portland University and the Northwestern College of Law .
# 5:	He is married and the father of three children .
# 6:		Helping foreign countries to build a sound political structure is more important than aiding them economically , E. M. Martin , assistant secretary of state for economic affairs told members of the World Affairs Council Monday night .
# 7:		Martin , who has been in office in Washington , D. C. , for 13 months spoke at the council's annual meeting at the Multnomah Hotel .
# ...

# %%
from nltk import sent_tokenize, word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['\n\tVincent G. Ierulli has been appointed temporary assistant district attorney , it was announced Monday by Charles E. Raymond , District Attorney .',
#  'Ierulli will replace Desmond D. Connall who has been called to active military service but is expected back on the job by March 31 .',
#  'Ierulli , 29 , has been practicing in Portland since November , 1959 .',
#  'He is a graduate of Portland University and the Northwestern College of Law .',
#  'He is married and the father of three children .',
#  'Helping foreign countries to build a sound political structure is more important than aiding them economically , E. M. Martin , assistant secretary of state for economic affairs told members of the World Affairs Council Monday night .',
#  "Martin , who has been in office in Washington , D. C. , for 13 months spoke at the council's annual meeting at the Multnomah Hotel .",
# ...

# %%
for sent in sent_tokenize(data2):
  print(word_tokenize(sent))
# Out:
# ['Vincent', 'G.', 'Ierulli', 'has', 'been', 'appointed', 'temporary', 'assistant', 'district', 'attorney', ',', 'it', 'was', 'announced', 'Monday', 'by', 'Charles', 'E.', 'Raymond', ',', 'District', 'Attorney', '.']
# ['Ierulli', 'will', 'replace', 'Desmond', 'D.', 'Connall', 'who', 'has', 'been', 'called', 'to', 'active', 'military', 'service', 'but', 'is', 'expected', 'back', 'on', 'the', 'job', 'by', 'March', '31', '.']
# ['Ierulli', ',', '29', ',', 'has', 'been', 'practicing', 'in', 'Portland', 'since', 'November', ',', '1959', '.']
# ['He', 'is', 'a', 'graduate', 'of', 'Portland', 'University', 'and', 'the', 'Northwestern', 'College', 'of', 'Law', '.']
# ['He', 'is', 'married', 'and', 'the', 'father', 'of', 'three', 'children', '.']
# ...

# %%
from nltk.corpus import stopwords
stopwords_en = stopwords.words('english')

# %%
print(stopwords_en)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
single_tokenized_lowered = list(map(str.lower, word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['vincent', 'g.', 'ierulli', 'has', 'been', 'appointed', 'temporary', 'assistant', 'district', 'attorney', ',', 'it', 'was', 'announced', 'monday', 'by', 'charles', 'e.', 'raymond', ',', 'district', 'attorney', '.', 'ierulli', 'will', 'replace', 'desmond', 'd.', 'connall', 'who', 'has', 'been', 'called', 'to', 'active', 'military', 'service', 'but', 'is', 'expected', 'back', 'on', 'the', 'job', 'by', 'march', '31', '.', 'ierulli', ',', '29', ',', 'has', 'been', 'practicing', 'in', 'portland', 'since', 'november', ',', '1959', '.', 'he', 'is', 'a', 'graduate', 'of', 'portland', 'university', 'and', 'the', 'northwestern', 'college', 'of', 'law', '.', 'he', 'is', 'married', 'and', 'the', 'father', 'of', 'three', 'children', '.', 'helping', 'foreign', 'countries', 'to', 'build', 'a', 'sound', 'political', 'structure', 'is', 'more', 'important', 'than', 'aiding', 'them', 'economically', ',', 'e.', 'm.', 'martin', ',', 'assistant', 'secretary', 'of', 'state', 'for', 'economic', 'affairs', 
# ...

# %%
stopwords_en = set(stopwords.words('english'))

print([word for word in single_tokenized_lowered if word not in stopwords_en])
# Out:
# ['vincent', 'g.', 'ierulli', 'appointed', 'temporary', 'assistant', 'district', 'attorney', ',', 'announced', 'monday', 'charles', 'e.', 'raymond', ',', 'district', 'attorney', '.', 'ierulli', 'replace', 'desmond', 'd.', 'connall', 'called', 'active', 'military', 'service', 'expected', 'back', 'job', 'march', '31', '.', 'ierulli', ',', '29', ',', 'practicing', 'portland', 'since', 'november', ',', '1959', '.', 'graduate', 'portland', 'university', 'northwestern', 'college', 'law', '.', 'married', 'father', 'three', 'children', '.', 'helping', 'foreign', 'countries', 'build', 'sound', 'political', 'structure', 'important', 'aiding', 'economically', ',', 'e.', 'm.', 'martin', ',', 'assistant', 'secretary', 'state', 'economic', 'affairs', 'told', 'members', 'world', 'affairs', 'council', 'monday', 'night', '.', 'martin', ',', 'office', 'washington', ',', 'd.', 'c.', ',', '13', 'months', 'spoke', 'council', "'s", 'annual', 'meeting', 'multnomah', 'hotel', '.', 'told', '350', 'persons', '
# ...

# %%
from string import punctuation
print('From string.punctuation: ', type(punctuation), punctuation)
# Out:
# From string.punctuation:  <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_with_punctuation = stopwords_en.union(set(punctuation))

print([word for word in single_tokenized_lowered if word not in stopwords_en_with_punctuation])
# Out:
# ['vincent', 'g.', 'ierulli', 'appointed', 'temporary', 'assistant', 'district', 'attorney', 'announced', 'monday', 'charles', 'e.', 'raymond', 'district', 'attorney', 'ierulli', 'replace', 'desmond', 'd.', 'connall', 'called', 'active', 'military', 'service', 'expected', 'back', 'job', 'march', '31', 'ierulli', '29', 'practicing', 'portland', 'since', 'november', '1959', 'graduate', 'portland', 'university', 'northwestern', 'college', 'law', 'married', 'father', 'three', 'children', 'helping', 'foreign', 'countries', 'build', 'sound', 'political', 'structure', 'important', 'aiding', 'economically', 'e.', 'm.', 'martin', 'assistant', 'secretary', 'state', 'economic', 'affairs', 'told', 'members', 'world', 'affairs', 'council', 'monday', 'night', 'martin', 'office', 'washington', 'd.', 'c.', '13', 'months', 'spoke', 'council', "'s", 'annual', 'meeting', 'multnomah', 'hotel', 'told', '350', 'persons', 'united', 'states', 'challenge', 'help', 'countries', 'build', 'societies', 'ways', 'f
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in single_tokenized_lowered:
  print(porter.stem(word), word)
# Out:
# vincent vincent
# g. g.
# ierulli ierulli
# ha has
# been been
# appoint appointed
# temporari temporary
# assist assistant
# district district
# attorney attorney
# , ,
# it it
# wa was
# announc announced
# monday monday
# by by
# charl charles
# e. e.
# raymond raymond
# , ,
# district district
# attorney attorney
# . .
# ierulli ierulli
# will will
# replac replace
# desmond desmond
# d. d.
# connal connall
# who who
# ha has
# been been
# call called
# to to
# activ active
# militari military
# servic service
# but but
# is is
# expect expected
# back back
# on on
# the the
# job job
# by by
# march march
# 31 31
# . .
# ierulli ierulli
# , ,
# 29 29
# , ,
# ha has
# been been
# practic practicing
# in in
# portland portland
# sinc since
# novemb november
# , ,
# 1959 1959
# . .
# he he
# is is
# a a
# graduat graduate
# of of
# portland portland
# univers university
# and and
# the the
# northwestern northwestern
# colleg college
# of of
# law law
# . .
# he he
# is is
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

for word in single_tokenized_lowered:
  print(wnl.lemmatize(word), word)
# Out:
# vincent vincent
# g. g.
# ierulli ierulli
# ha has
# been been
# appointed appointed
# temporary temporary
# assistant assistant
# district district
# attorney attorney
# , ,
# it it
# wa was
# announced announced
# monday monday
# by by
# charles charles
# e. e.
# raymond raymond
# , ,
# district district
# attorney attorney
# . .
# ierulli ierulli
# will will
# replace replace
# desmond desmond
# d. d.
# connall connall
# who who
# ha has
# been been
# called called
# to to
# active active
# military military
# service service
# but but
# is is
# expected expected
# back back
# on on
# the the
# job job
# by by
# march march
# 31 31
# . .
# ierulli ierulli
# , ,
# 29 29
# , ,
# ha has
# been been
# practicing practicing
# in in
# portland portland
# since since
# november november
# , ,
# 1959 1959
# . .
# he he
# is is
# a a
# graduate graduate
# of of
# portland portland
# university university
# and and
# the the
# northwestern northwestern
# college college
# of of
# law law
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
stop_words = set(stopwords_en)
tokenized = sent_tokenize(data2)

for line in tokenized:
  wordslist = nltk.word_tokenize(line)
  wordslist = [w for w in wordslist if not w in stop_words]
  tagged = nltk.pos_tag(wordslist)
  print(tagged)
# Out:
# [('Vincent', 'NNP'), ('G.', 'NNP'), ('Ierulli', 'NNP'), ('appointed', 'VBD'), ('temporary', 'JJ'), ('assistant', 'NN'), ('district', 'NN'), ('attorney', 'NN'), (',', ','), ('announced', 'VBD'), ('Monday', 'NNP'), ('Charles', 'NNP'), ('E.', 'NNP'), ('Raymond', 'NNP'), (',', ','), ('District', 'NNP'), ('Attorney', 'NNP'), ('.', '.')]
# [('Ierulli', 'NNP'), ('replace', 'VB'), ('Desmond', 'NNP'), ('D.', 'NNP'), ('Connall', 'NNP'), ('called', 'VBD'), ('active', 'JJ'), ('military', 'JJ'), ('service', 'NN'), ('expected', 'VBN'), ('back', 'RB'), ('job', 'NN'), ('March', 'NNP'), ('31', 'CD'), ('.', '.')]
# [('Ierulli', 'NNP'), (',', ','), ('29', 'CD'), (',', ','), ('practicing', 'VBG'), ('Portland', 'NNP'), ('since', 'IN'), ('November', 'NNP'), (',', ','), ('1959', 'CD'), ('.', '.')]
# [('He', 'PRP'), ('graduate', 'NN'), ('Portland', 'NNP'), ('University', 'NNP'), ('Northwestern', 'NNP'), ('College', 'NNP'), ('Law', 'NNP'), ('.', '.')]
# ...

# %%
print(tokenized)
# Out:
# ['\n\tVincent G. Ierulli has been appointed temporary assistant district attorney , it was announced Monday by Charles E. Raymond , District Attorney .', 'Ierulli will replace Desmond D. Connall who has been called to active military service but is expected back on the job by March 31 .', 'Ierulli , 29 , has been practicing in Portland since November , 1959 .', 'He is a graduate of Portland University and the Northwestern College of Law .', 'He is married and the father of three children .', 'Helping foreign countries to build a sound political structure is more important than aiding them economically , E. M. Martin , assistant secretary of state for economic affairs told members of the World Affairs Council Monday night .', "Martin , who has been in office in Washington , D. C. , for 13 months spoke at the council's annual meeting at the Multnomah Hotel .", "He told some 350 persons that the United States' challenge was to help countries build their own societies their own ways , fo
# ...

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
sentences = nltk.sent_tokenize(data2)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences =    [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences =   nltk.ne_chunk_sents(tagged_sentences, binary=True)

def extract_entity_names(t):
  entity_names = []

  if hasattr(t, 'label') and t.label:
    if t.label() == 'NE':
      entity_names.append(' '.join([child[0] for child in t]))
    else:
      for child in t:
        entity_names.extend(extract_entity_names(child))
  return entity_names

entity_names = []
for tree in chunked_sentences:
  entity_names.extend(extract_entity_names(tree))

# %%
set(entity_names)
# Out:
# {'AP',
#  'Al Ullman',
#  'Attorney Dwight',
#  'Barbara Njust',
#  'Barnes',
#  'Beaverton School District No',
#  'Blaine Whipple',
#  'Board',
#  'Chairman',
#  'Charles',
#  'Christ',
#  'Church',
#  'Dean Bryson',
#  'Democratic Party',
#  'Desmond',
#  'District Attorney',
#  'Donald Huffman',
#  'Dwight M. Steeves',
#  'East Germany',
#  'Election',
#  'Emerald Empire Kiwanis Club',
#  'Eugene',
#  'Frank Lee',
#  'God',
#  'Hatfield',
#  'Ierulli',
#  'Illinois',
#  'Individual',
#  'Jack Lowe',
#  'James',
#  'James Culbertson',
#  'Labor Arthur Goldberg',
#  'Labor Commissioner Norman Nilsen',
#  'Lord Jesus Christ',
#  'Los Angeles',
#  'Mark Hatfield',
#  'Martin',
#  'Masonic Temple',
#  'Memorial Coliseum',
#  'Miles',
#  'Mr. Brandt',
#  'Mr. Zimmerman',
#  'Multnomah County Circuit Judge',
#  'Multnomah Hotel',
#  'New',
#  'New Testament',
#  'Northwestern College',
#  'Oak Grove',
#  'Oak Lodge Water',
#  'Oregon',
#  'Patience',
#  'Philip Weinstein',
# ...
